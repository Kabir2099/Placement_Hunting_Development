# %%
import pandas as pd

# %%
import seaborn as sns

# Load the mpg dataset
mpg = sns.load_dataset('mpg')

# Show the first few rows of the dataset
print(mpg.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.shape
# Out:
# (398, 9)

# %%
# min
mpg['mpg'].min()
# Out:
# 9.0

# %%
mpg['mpg'].agg('min',axis=0)
# Out:
# 9.0

# %%
col = ['mpg', 'acceleration']

# %%
col
# Out:
# ['mpg', 'acceleration']

# %%
mpg[col].agg(['min','max'])
# Out:
#       mpg  acceleration
# min   9.0           8.0
# max  46.6          24.8

# %%
mpg.agg{}

# %% [markdown]
# # Group by function

# %%
mpg['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
mpg.groupby(['model_year']).count()[['name','origin']]
# Out:
#             name  origin
# model_year
# 70            29      29
# 71            28      28
# 72            28      28
# 73            40      40
# 74            27      27
# 75            30      30
# 76            34      34
# 77            28      28
# 78            36      36
# 79            29      29
# 80            29      29
# 81            29      29
# 82            31      31

# %% [markdown]
# # about the effect of model year and number of cylinders on horsepower

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
dummy= mpg.groupby(['cylinders','model_year']).agg({'horsepower':['min','max','mean']})

# %%
dummy
# Out:
#                      horsepower
#                             min    max        mean
# cylinders model_year
# 3         72               97.0   97.0   97.000000
#           73               90.0   90.0   90.000000
#           77              110.0  110.0  110.000000
#           80              100.0  100.0  100.000000
# 4         70               46.0  113.0   87.714286
#           71               60.0   95.0   77.583333
#           72               54.0  112.0   85.142857
#           73               46.0  112.0   82.909091
#           74               52.0   97.0   74.000000
#           75               53.0  115.0   84.916667
#           76               52.0  102.0   75.600000
#           77               58.0  110.0   78.785714
#           78               48.0  115.0   79.705882
#           79               65.0   90.0   75.750000
#           80               48.0  105.0   74.043478
#           81               58.0  100.0   72.950000
# ...

# %%
dummy.columns=['hp_min', 'hp_max', 'hp_mean']

# %%
dummy
# Out:
#                       hp_min  hp_max     hp_mean
# cylinders model_year
# 3         72            97.0    97.0   97.000000
#           73            90.0    90.0   90.000000
#           77           110.0   110.0  110.000000
#           80           100.0   100.0  100.000000
# 4         70            46.0   113.0   87.714286
#           71            60.0    95.0   77.583333
#           72            54.0   112.0   85.142857
#           73            46.0   112.0   82.909091
#           74            52.0    97.0   74.000000
#           75            53.0   115.0   84.916667
#           76            52.0   102.0   75.600000
#           77            58.0   110.0   78.785714
#           78            48.0   115.0   79.705882
#           79            65.0    90.0   75.750000
#           80            48.0   105.0   74.043478
#           81            58.0   100.0   72.950000
#           82            52.0    96.0   79.148148
# 5         78           103.0   103.0  103.000000
# ...

# %%
# groupy to dataframe

# %%
dummy.reset_index()
# Out:
#     cylinders  model_year  hp_min  hp_max     hp_mean
# 0           3          72    97.0    97.0   97.000000
# 1           3          73    90.0    90.0   90.000000
# 2           3          77   110.0   110.0  110.000000
# 3           3          80   100.0   100.0  100.000000
# 4           4          70    46.0   113.0   87.714286
# 5           4          71    60.0    95.0   77.583333
# 6           4          72    54.0   112.0   85.142857
# 7           4          73    46.0   112.0   82.909091
# 8           4          74    52.0    97.0   74.000000
# 9           4          75    53.0   115.0   84.916667
# 10          4          76    52.0   102.0   75.600000
# 11          4          77    58.0   110.0   78.785714
# 12          4          78    48.0   115.0   79.705882
# 13          4          79    65.0    90.0   75.750000
# 14          4          80    48.0   105.0   74.043478
# 15          4          81    58.0   100.0   72.950000
# ...

# %%
grp1 = mpg.groupby(['cylinders','model_year']).agg({'horsepower':['min','max','mean'],'acceleration':['min']})

# %%
grp1
# Out:
#                      horsepower                    acceleration
#                             min    max        mean          min
# cylinders model_year
# 3         72               97.0   97.0   97.000000         13.5
#           73               90.0   90.0   90.000000         13.5
#           77              110.0  110.0  110.000000         13.5
#           80              100.0  100.0  100.000000         12.5
# 4         70               46.0  113.0   87.714286         12.5
#           71               60.0   95.0   77.583333         14.0
#           72               54.0  112.0   85.142857         14.5
#           73               46.0  112.0   82.909091         14.0
#           74               52.0   97.0   74.000000         14.0
#           75               53.0  115.0   84.916667         13.5
#           76               52.0  102.0   75.600000         12.2
#           77               58.0  110.0   78.785714         12.8
# ...

# %% [markdown]
# # ABout the relationship between model year and accelration of cars

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.groupby('model_year').apply(lambda x: x.sort_values('acceleration')).reset_index(drop=True)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    14.0          8         340.0       160.0    3609           8.0
# 1    14.0          8         440.0       215.0    4312           8.5
# 2    15.0          8         390.0       190.0    3850           8.5
# 3    14.0          8         454.0       220.0    4354           9.0
# 4    15.0          8         400.0       150.0    3761           9.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         112.0        88.0    2640          18.6
# 394  31.0          4         119.0        82.0    2720          19.4
# 395  28.0          4         112.0        88.0    2605          19.6
# 396  23.0          4         151.0         NaN    3035          20.5
# 397  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                      name
# 0            70     usa        plymouth 'cuda 340
# ...

# %% [markdown]
# # combining data fram

# %%
d1 = {'a':[1,2],'b':[5,6]}
d2 = {'a':[6,7], 'b':[9,10]}

# %%
d1
# Out:
# {'a': [1, 2], 'b': [5, 6]}

# %%
d2
# Out:
# {'a': [6, 7], 'b': [9, 10]}

# %%
df2 = pd.DataFrame(d1)

# %%
df3 = pd.DataFrame(d2)

# %%
df3
# Out:
#    a   b
# 0  6   9
# 1  7  10

# %%
pd.concat([df2, df3])  # concat([list of dataframe], sort)
# Out:
#    a   b
# 0  1   5
# 1  2   6
# 0  6   9
# 1  7  10

# %%
df4 = pd.concat([df2, df3], sort=True)

# %%
df4
# Out:
#    a   b
# 0  1   5
# 1  2   6
# 0  6   9
# 1  7  10

# %%
d1 = {"Employee":['kabir','sam','raj'],'Group':['sde','admin','eng']}

# %%
d2 = {'Employee':['kabir','sam','raj'],'Hire_Date':['2024','2023','2022']}

# %%
pd.DataFrame(d1)
# Out:
#   Employee  Group
# 0    kabir    sde
# 1      sam  admin
# 2      raj    eng

# %%
df5 = pd.DataFrame(d1)

# %%
df6 = pd.DataFrame(d2)
df6
# Out:
#   Employee Hire_Date
# 0    kabir      2024
# 1      sam      2023
# 2      raj      2022

# %%
pd.merge(df5,df6, how='inner')
# Out:
#   Employee  Group Hire_Date
# 0    kabir    sde      2024
# 1      sam  admin      2023
# 2      raj    eng      2022

# %%
d3 = {'emp':['kabir','sam','raj'],'Hire_Date':['2024','2023','2022']}

# %%
df7 = pd.DataFrame(d3)

# %%
df7
# Out:
#      emp Hire_Date
# 0  kabir      2024
# 1    sam      2023
# 2    raj      2022

# %%
df5
# Out:
#   Employee  Group
# 0    kabir    sde
# 1      sam  admin
# 2      raj    eng

# %%
pd.merge(df5, df7,left_on = 'Employee', right_on = 'emp')
# Out:
#   Employee  Group    emp Hire_Date
# 0    kabir    sde  kabir      2024
# 1      sam  admin    sam      2023
# 2      raj    eng    raj      2022

# %% [markdown]
# # crosstab

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %% [markdown]
# # frqeuency distributiion of diff number of cylinders across diff year

# %%
pd.crosstab(mpg['model_year'],mpg['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# # how to handle

# %%
# dropna ->remove the row which contain nan value

# %%
back = mpg.copy()

# %%
back.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
x = back.dropna()

# %%
x.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
back.dropna(inplace=True)

# %%
back.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
back = mpg.copy()

# %%
back.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
back.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
x = back.fillna(67)

# %%
x.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
back.fillna(mpg['horsepower'].mean(),inplace=True)

# %%
back.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# # Pivot table

# %%
pd.pivot_table(mpg, index='model_year', columns='origin',values='mpg' ,aggfunc='min')
# Out:
# origin      europe  japan   usa
# model_year
# 70            24.0   24.0   9.0
# 71            27.0   25.0  12.0
# 72            18.0   19.0  11.0
# 73            19.0   18.0  11.0
# 74            24.0   24.0  13.0
# 75            22.0   24.0  13.0
# 76            16.5   19.0  13.0
# 77            21.5   21.5  15.0
# 78            16.2   21.1  17.5
# 79            25.4   31.8  15.5
# 80            29.8   23.7  19.1
# 81            28.1   24.2  17.6
# 82            36.0   31.0  22.0

# %%
mpg['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
pd.pivot_table(mpg, index='model_year', columns='origin',values=['mpg','horsepower'] ,aggfunc='sum')
# Out:
#            horsepower                    mpg
# origin         europe   japan     usa europe  japan    usa
# model_year
# 70              431.0   183.0  3673.0  126.0   51.0  336.0
# 71              296.0   317.0  2277.0  115.0  118.0  362.0
# 72              398.0   469.0  2498.0  110.0  121.0  293.0
# 73              573.0   394.0  4252.0  168.0   80.0  436.0
# 74              445.0   435.0  1570.0  162.0  176.0  275.0
# 75              537.0   321.0  2174.0  147.0  110.0  351.0
# 76              701.0   306.0  2431.0  194.0  112.0  427.5
# 77              324.0   487.0  2131.0  117.0  164.5  373.0
# 78              595.0   634.0  2360.0  149.7  237.5  479.0
# 79              288.0   130.0  2517.0  121.8   65.9  540.0
# 80              534.0  1025.0   533.0  335.6  460.2  181.4
# 81              230.0   940.0  1099.0  126.3  395.5  357.9
# 82              126.0   666.0  1652.0   80.0  314.0  589.0
