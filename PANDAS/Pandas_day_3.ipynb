# %%
import pandas as pd

# %%
import seaborn as sns

# Load the mpg dataset
mpg = sns.load_dataset('mpg')

# Show the first few rows of the dataset
print(mpg.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
# check null value

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# Retrive details of all the cars whicvh built in 72

# %%
mpg['model_year'] == 72
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: model_year, Length: 398, dtype: bool

# %%
mpg[mpg['model_year'] == 72]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
# 62  13.0          8         350.0       165.0    4274          12.0
# 63  14.0          8         400.0       175.0    4385          12.0
# 64  15.0          8         318.0       150.0    4135          13.5
# 65  14.0          8         351.0       153.0    4129          13.0
# 66  17.0          8         304.0       150.0    3672          11.5
# 67  11.0          8         429.0       208.0    4633          11.0
# 68  13.0          8         350.0       155.0    4502          13.5
# 69  12.0          8         350.0       160.0    4456          13.5
# ...

# %%
mpg.loc[mpg['model_year'] == 72]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 57  24.0          4         113.0        95.0    2278          15.5
# 58  25.0          4          97.5        80.0    2126          17.0
# 59  23.0          4          97.0        54.0    2254          23.5
# 60  20.0          4         140.0        90.0    2408          19.5
# 61  21.0          4         122.0        86.0    2226          16.5
# 62  13.0          8         350.0       165.0    4274          12.0
# 63  14.0          8         400.0       175.0    4385          12.0
# 64  15.0          8         318.0       150.0    4135          13.5
# 65  14.0          8         351.0       153.0    4129          13.0
# 66  17.0          8         304.0       150.0    3672          11.5
# 67  11.0          8         429.0       208.0    4633          11.0
# 68  13.0          8         350.0       155.0    4502          13.5
# 69  12.0          8         350.0       160.0    4456          13.5
# ...

# %% [markdown]
# # cars  origin = japan and cylinders having = 6

# %%
mpg['origin'] == 'japan'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: origin, Length: 398, dtype: bool

# %%
mpg['cylinders'] ==6
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: cylinders, Length: 398, dtype: bool

# %%
mpg[(mpg['origin']=='japan') & (mpg['cylinders']==6)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 123  20.0          6         156.0       122.0    2807          13.5
# 210  19.0          6         156.0       108.0    2930          15.5
# 241  22.0          6         146.0        97.0    2815          14.5
# 333  32.7          6         168.0       132.0    2910          11.4
# 361  25.4          6         168.0       116.0    2900          12.6
# 362  24.2          6         146.0       120.0    2930          13.8
#
#      model_year origin               name
# 123          73  japan     toyota mark ii
# 210          76  japan     toyota mark ii
# 241          77  japan         datsun 810
# 333          80  japan      datsun 280-zx
# 361          81  japan    toyota cressida
# 362          81  japan  datsun 810 maxima

# %%
(mpg['origin']=='japan') & (mpg['cylinders']==6)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %% [markdown]
# # data_set_name[condition] #way

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# mpg>29 and horsepower <93.5 and wieght <2500

# %%
(mpg['mpg']>29) &(mpg['horsepower']<93.5) & (mpg['weight']<2500)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393    False
# 394     True
# 395     True
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
mpg[(mpg['mpg']>29) &(mpg['horsepower']<93.5) & (mpg['weight']<2500)].head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0        70.0    2074          19.5
# 52   30.0          4          88.0        76.0    2065          14.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
#
#      model_year  origin                 name
# 51           71  europe          peugeot 304
# 52           71  europe            fiat 124b
# 53           71   japan  toyota corolla 1200
# 54           71   japan          datsun 1200
# 129          74   japan          datsun b210

# %% [markdown]
# # displacement > 262 and weight in the range(2800, 3600)

# %%
(mpg['displacement']>262) & ((mpg['weight']>=2800) & (mpg['weight']<=3600))
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
mpg[(mpg['displacement']>262) & ((mpg['weight']>=2800) & (mpg['weight']<=3600))]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# ...

# %%
x = (mpg['displacement']>262) & ((mpg['weight']>=2800) & (mpg['weight']<=3600))

# %%
x
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
mpg[x]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# ...

# %%
df = mpg[x]

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# ...

# %% [markdown]
# # Masking operation

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 121  15.0          8         318.0       150.0    3399          11.0
# 166  13.0          8         302.0       129.0    3169          12.0
# 251  20.2          8         302.0       139.0    3570          12.8
# 262  19.2          8         305.0       145.0    3425          13.2
# 264  18.1          8         302.0       139.0    3205          11.2
#
#      model_year origin                          name
# 0            70    usa     chevrolet chevelle malibu
# ...

# %%
marks =[{'chem': 67, 'phy': 23, 'maths':56},
          {'chem': 13, 'phy': 63, 'maths':56},
          {'chem': 67, 'phy': 23, 'maths':16},
          {'chem': 77, 'phy': 53, 'maths':6}]

# %%
marks
# Out:
# [{'chem': 67, 'phy': 23, 'maths': 56},
#  {'chem': 13, 'phy': 63, 'maths': 56},
#  {'chem': 67, 'phy': 23, 'maths': 16},
#  {'chem': 77, 'phy': 53, 'maths': 6}]

# %%
marks_df = pd.DataFrame(marks, index=['sam','ram','rohit','xy'])

# %%
marks_df
# Out:
#        chem  phy  maths
# sam      67   23     56
# ram      13   63     56
# rohit    67   23     16
# xy       77   53      6

# %%
f = marks_df<33

# %%
marks_df.mask(f, 'Fail') # mask(condition, value)
# Out:
#        chem   phy maths
# sam      67  Fail    56
# ram    Fail    63    56
# rohit    67  Fail  Fail
# xy       77    53  Fail

# %% [markdown]
# # sort

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.sort_values(by='acceleration')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 7    14.0          8         440.0       215.0    4312           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
# ..    ...        ...           ...         ...     ...           ...
# 300  23.9          8         260.0        90.0    3420          22.2
# 59   23.0          4          97.0        54.0    2254          23.5
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 299  27.2          4         141.0        71.0    3190          24.8
#
#      model_year  origin                               name
# 11           70     usa                 plymouth 'cuda 340
# ...

# %%
mpg.sort_values(by='acceleration',  ascending=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 299  27.2          4         141.0        71.0    3190          24.8
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
# 59   23.0          4          97.0        54.0    2254          23.5
# 300  23.9          8         260.0        90.0    3420          22.2
# ..    ...        ...           ...         ...     ...           ...
# 116  16.0          8         400.0       230.0    4278           9.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 9    15.0          8         390.0       190.0    3850           8.5
# 11   14.0          8         340.0       160.0    3609           8.0
#
#      model_year  origin                               name
# 299          79  europe                        peugeot 504
# ...

# %%
mpg.sort_values('mpg')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...

# %%
mpg.sort_values(by=['mpg','acceleration'], ascending=(1,0))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 26   10.0          8         307.0       200.0    4376          15.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 27   11.0          8         318.0       210.0    4382          13.5
# ..    ...        ...           ...         ...     ...           ...
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 325  44.3          4          90.0        48.0    2085          21.7
# 329  44.6          4          91.0        67.0    1850          13.8
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year  origin                  name
# 28           70     usa              hi 1200d
# ...

# %% [markdown]
# # Reset_index

# %%
marks_df
# Out:
#        chem  phy  maths
# sam      67   23     56
# ram      13   63     56
# rohit    67   23     16
# xy       77   53      6

# %%
marks_df.index
# Out:
# Index(['sam', 'ram', 'rohit', 'xy'], dtype='object')

# %%
marks_df.reset_index()
# Out:
#    index  chem  phy  maths
# 0    sam    67   23     56
# 1    ram    13   63     56
# 2  rohit    67   23     16
# 3     xy    77   53      6

# %%
marks_df
# Out:
#        chem  phy  maths
# sam      67   23     56
# ram      13   63     56
# rohit    67   23     16
# xy       77   53      6

# %%
marks_df.reset_index(inplace=True,drop=True) # index -> delete

# %%
marks_df
# Out:
#    index  chem  phy  maths
# 0    sam    67   23     56
# 1    ram    13   63     56
# 2  rohit    67   23     16
# 3     xy    77   53      6

# %%
marks_df
# Out:
#    index  chem  phy  maths
# 0    sam    67   23     56
# 1    ram    13   63     56
# 2  rohit    67   23     16
# 3     xy    77   53      6

# %%
marks_df.drop(columns='index', inplace=True)

# %%
marks_df
# Out:
#    chem  phy  maths
# 0    67   23     56
# 1    13   63     56
# 2    67   23     16
# 3    77   53      6

# %%
marks_df+5
# Out:
#    chem  phy  maths
# 0    72   28     61
# 1    18   68     61
# 2    72   28     21
# 3    82   58     11

# %%
marks_df
# Out:
#    chem  phy  maths
# 0    67   23     56
# 1    13   63     56
# 2    67   23     16
# 3    77   53      6

# %%
marks_df + [10,20,30]
# Out:
#    chem  phy  maths
# 0    77   43     86
# 1    23   83     86
# 2    77   43     46
# 3    87   73     36

# %% [markdown]
# # apply function

# %%
import numpy as np

# %%
marks_df
# Out:
#    chem  phy  maths
# 0    67   23     56
# 1    13   63     56
# 2    67   23     16
# 3    77   53      6

# %%
marks_df.apply(np.sum, axis=0) # col wise
# Out:
# chem     224
# phy      162
# maths    134
# dtype: int64

# %%
marks_df.apply(np.sum, axis=1) # row wise
# Out:
# 0    146
# 1    132
# 2    106
# 3    136
# dtype: int64

# %%
marks_df.apply(lambda x: x+5, axis=0)
# Out:
#    chem  phy  maths
# 0    72   28     61
# 1    18   68     61
# 2    72   28     21
# 3    82   58     11

# %%
marks_df
# Out:
#    chem  phy  maths
# 0    67   23     56
# 1    13   63     56
# 2    67   23     16
# 3    77   53      6

# %% [markdown]
# # want marks>50

# %%
marks_df.apply(lambda x: x>20, axis=0)
# Out:
#     chem   phy  maths
# 0   True  True   True
# 1  False  True   True
# 2   True  True  False
# 3   True  True  False

# %%
marks_df[marks_df.apply(lambda x: x>20, axis=0)]
# Out:
#    chem  phy  maths
# 0  67.0   23   56.0
# 1   NaN   63   56.0
# 2  67.0   23    NaN
# 3  77.0   53    NaN

# %%
marks_df.apply(np.mean, axis=1)
# Out:
# 0    48.666667
# 1    44.000000
# 2    35.333333
# 3    45.333333
# dtype: float64

# %% [markdown]
# # value_counts()

# %%
mpg['origin'].unique() # value return
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
mpg['origin'].nunique() # number of unique value
# Out:
# 3

# %%
mpg['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64
